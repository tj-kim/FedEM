# %%
! python run_experiment.py cifar100 FedAvg --n_learners 1 --n_rounds 200 --bz 128 --lr 0.01  --lr_scheduler multi_step --log_freq 5 --device cuda --optimizer sgd --seed 1234 --verbose 1  --save_path weights/cifar100/fedAvg/
# Out:
# ==> Clients initialization..
# ===> Building data iterators..
# 100%|████████████████████████████████████████| 100/100 [00:00<00:00, 343.66it/s]
# ===> Initializing clients..
# 100%|█████████████████████████████████████████| 100/100 [00:14<00:00,  6.76it/s]
# ==> Test Clients initialization..
# ===> Building data iterators..
# 0it [00:00, ?it/s]
# ===> Initializing clients..
# 0it [00:00, ?it/s]
# ++++++++++++++++++++++++++++++
# Global..
# Train Loss: 4.611 | Train Acc: 1.104% |Test Loss: 4.612 | Test Acc: 1.117% |
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ################################################################################
# Training..
#   2%|▊                                        | 4/200 [02:44<2:14:55, 41.30s/it]++++++++++++++++++++++++++++++
# Global..
# Train Loss: 4.438 | Train Acc: 8.969% |Test Loss: 4.444 | Test Acc: 8.300% |
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
